# %%
import pandas as pd

# %%
df=pd.read_csv("/content/transactions_train.csv")

# %%
df.head()
# Out:
#    transaction_amount     transaction_date transaction_channel  is_fraud  \
# 0              3606.0  2024-11-01 00:00:06                   w         0
# 1               599.0  2024-11-01 00:00:08              mobile         0
# 2                30.0  2024-11-01 00:00:12                   w         0
# 3                99.0  2024-11-01 00:00:34              mobile         0
# 4               299.0  2024-11-01 00:01:23              mobile         0
#
#    transaction_payment_mode_anonymous  payment_gateway_bank_anonymous  \
# 0                                  10                               0
# 1                                  10                               6
# 2                                  10                               0
# 3                                  11                               0
# 4                                  11                               0
#
#    payer_browser_anonymous                              payer_email_anonymous  \
# ...

# %%
df.describe(include='all')
# Out:
#         transaction_amount     transaction_date transaction_channel  \
# count         1.728540e+05               172926              172926
# unique                 NaN               127176                   9
# top                    NaN  2024-11-05 15:17:54                   w
# freq                   NaN                   19              114369
# mean          1.577841e+03                  NaN                 NaN
# std           3.134730e+04                  NaN                 NaN
# min           1.000000e+00                  NaN                 NaN
# 25%           4.000000e+01                  NaN                 NaN
# 50%           2.059000e+02                  NaN                 NaN
# 75%           5.000000e+02                  NaN                 NaN
# max           7.000035e+06                  NaN                 NaN
#
#              is_fraud  transaction_payment_mode_anonymous  \
# count   172926.000000                        172926.00000
# ...

# %%
df.isnull().sum()  # Count missing values in each column
# Out:
# transaction_amount                        72
# transaction_date                           0
# transaction_channel                        0
# is_fraud                                   0
# transaction_payment_mode_anonymous         0
# payment_gateway_bank_anonymous             0
# payer_browser_anonymous                    0
# payer_email_anonymous                     15
# payee_ip_anonymous                         0
# payer_mobile_anonymous                104315
# transaction_id_anonymous                   0
# payee_id_anonymous                         0
# dtype: int64

# %%
df.nunique()  # Number of unique values per column
# Out:
# transaction_amount                      9816
# transaction_date                      127176
# transaction_channel                        9
# is_fraud                                   2
# transaction_payment_mode_anonymous        13
# payment_gateway_bank_anonymous            54
# payer_browser_anonymous                 2787
# payer_email_anonymous                  41146
# payee_ip_anonymous                        46
# payer_mobile_anonymous                  1001
# transaction_id_anonymous              172926
# payee_id_anonymous                       414
# dtype: int64

# %%
# summary = {
#     "Shape": df.shape,
#     "Columns": df.columns.tolist(),
#     "Missing Values": df.isnull().sum().to_dict(),
#     "Unique Values": df.nunique().to_dict(),
#     "Data Types": df.dtypes.to_dict(),
#     "Fraud Class Distribution": df['is_fraud'].value_counts(normalize=True).to_dict()
# }

# import pprint
# pprint.pprint(summary)

# %%
print(df.columns)
# Out:
# Index(['transaction_amount', 'transaction_date', 'transaction_channel',
#        'is_fraud', 'transaction_payment_mode_anonymous',
#        'payment_gateway_bank_anonymous', 'payer_browser_anonymous',
#        'payer_email_anonymous', 'payee_ip_anonymous', 'payer_mobile_anonymous',
#        'transaction_id_anonymous', 'payee_id_anonymous'],
#       dtype='object')

# %%
df = df.drop(['transaction_id_anonymous', 'payer_mobile_anonymous'], axis=1, errors='ignore')

# %%
df.nunique()  # Number of unique values per column
# Out:
# transaction_amount                      9816
# transaction_date                      127176
# transaction_channel                        9
# is_fraud                                   2
# transaction_payment_mode_anonymous        13
# payment_gateway_bank_anonymous            54
# payer_browser_anonymous                 2787
# payer_email_anonymous                  41146
# payee_ip_anonymous                        46
# payee_id_anonymous                       414
# dtype: int64

# %%
df['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    172915
# 1        11
# Name: count, dtype: int64

# %%
df[df['is_fraud']==1]
# Out:
#         transaction_amount     transaction_date transaction_channel  is_fraud  \
# 9629                2500.0  2024-11-01 16:08:12              mobile         1
# 9764                 799.0  2024-11-01 16:15:12              mobile         1
# 27514               9338.0  2024-11-02 14:43:43              mobile         1
# 41176              11749.0  2024-11-03 11:14:07              mobile         1
# 66597               8999.0  2024-11-04 12:54:07              mobile         1
# 134329              1500.0  2024-11-06 08:36:20                   W         1
# 134618              3000.0  2024-11-06 08:56:48                   W         1
# 134815              4000.0  2024-11-06 09:08:18                   W         1
# 135218               300.0  2024-11-06 09:29:49                   W         1
# 147464              5000.0  2024-11-06 13:05:41                   W         1
# 155578             24990.0  2024-11-06 15:12:41              mobile         1
#
# ...

# %%
df = pd.get_dummies(df, columns=['transaction_channel'])

# %%
df.head(10)
# Out:
#    transaction_amount     transaction_date  is_fraud  \
# 0              3606.0  2024-11-01 00:00:06         0
# 1               599.0  2024-11-01 00:00:08         0
# 2                30.0  2024-11-01 00:00:12         0
# 3                99.0  2024-11-01 00:00:34         0
# 4               299.0  2024-11-01 00:01:23         0
# 5              3510.0  2024-11-01 00:01:44         0
# 6                10.0  2024-11-01 00:03:00         0
# 7               299.0  2024-11-01 00:03:06         0
# 8               205.9  2024-11-01 00:03:33         0
# 9               710.0  2024-11-01 00:03:41         0
#
#    transaction_payment_mode_anonymous  payment_gateway_bank_anonymous  \
# 0                                  10                               0
# 1                                  10                               6
# 2                                  10                               0
# 3                                  11                               0
# ...

# %%
df.dtypes
# Out:
# transaction_amount                    float64
# transaction_date                       object
# is_fraud                                int64
# transaction_payment_mode_anonymous      int64
# payment_gateway_bank_anonymous          int64
# payer_browser_anonymous                 int64
# payer_email_anonymous                  object
# payee_ip_anonymous                     object
# payee_id_anonymous                     object
# transaction_channel_#                    bool
# transaction_channel_1                    bool
# transaction_channel_5666                 bool
# transaction_channel_M                    bool
# transaction_channel_W                    bool
# transaction_channel_WEB                  bool
# transaction_channel_mobile               bool
# transaction_channel_npm                  bool
# transaction_channel_w                    bool
# dtype: object

# %%
# df['payer_email_count'] = df.groupby('payer_email_anonymous')['payer_email_anonymous'].transform('count')

# %%
email_counts = df['payer_email_anonymous'].value_counts()

# %%
df['payer_email_encoded'] = df['payer_email_anonymous'].map(email_counts)

# %%
df.head()
# Out:
#    transaction_amount     transaction_date  is_fraud  \
# 0              3606.0  2024-11-01 00:00:06         0
# 1               599.0  2024-11-01 00:00:08         0
# 2                30.0  2024-11-01 00:00:12         0
# 3                99.0  2024-11-01 00:00:34         0
# 4               299.0  2024-11-01 00:01:23         0
#
#    transaction_payment_mode_anonymous  payment_gateway_bank_anonymous  \
# 0                                  10                               0
# 1                                  10                               6
# 2                                  10                               0
# 3                                  11                               0
# 4                                  11                               0
#
#    payer_browser_anonymous                              payer_email_anonymous  \
# 0                     2993  ed340a2dbe10dda41f6f3d13062d039cb879008fc2106f...
# ...

# %%
# df = df.drop(['payer_email_anonymous'], axis=1, errors='ignore')

# %%
ip_counts = df['payee_ip_anonymous'].value_counts()
df['payer_ip_encoded'] = df['payee_ip_anonymous'].map(ip_counts)

# %%
# df['payer_ip_count'] = df.groupby('payee_ip_anonymous')['payee_ip_anonymous'].transform('count')

# %%
df = df.drop(['payee_ip_anonymous'], axis=1, errors='ignore')
df = df.drop(['payer_email_anonymous'], axis=1, errors='ignore')

# %%
df=df.drop(['transaction_date'], axis=1, errors='ignore')

# %%
payee_id_counts = df['payee_id_anonymous'].value_counts()
df['payee_id_encoded'] = df['payee_id_anonymous'].map(payee_id_counts)
df=df.drop(['payee_id_anonymous'], axis=1, errors='ignore')

# %%
payment_gateway_bank_counts = df['payment_gateway_bank_anonymous'].value_counts()
df['payment_gateway_bank_encoded'] = df['payment_gateway_bank_anonymous'].map(payment_gateway_bank_counts)
df=df.drop(['payment_gateway_bank_anonymous'], axis=1, errors='ignore')

payer_browser_counts = df['payer_browser_anonymous'].value_counts()
df['payer_browser_encoded'] = df['payer_browser_anonymous'].map(payer_browser_counts)
df=df.drop(['payer_browser_anonymous'], axis=1, errors='ignore')

# %%
df = pd.get_dummies(df, columns=['transaction_payment_mode_anonymous'])

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#    transaction_amount  is_fraud  transaction_channel_#  transaction_channel_1  \
# 0              3606.0         0                  False                  False
# 1               599.0         0                  False                  False
# 2                30.0         0                  False                  False
# 3                99.0         0                  False                  False
# 4               299.0         0                  False                  False
# 5              3510.0         0                  False                  False
# 6                10.0         0                  False                  False
# 7               299.0         0                  False                  False
# 8               205.9         0                  False                  False
# 9               710.0         0                  False                  False
#
#    transaction_channel_5666  transaction_channel_M  transaction_channel_W  \
# ...

# %%
df.nunique()  # Number of unique values per column
# Out:
# transaction_amount                       9816
# is_fraud                                    2
# transaction_channel_#                       2
# transaction_channel_1                       2
# transaction_channel_5666                    2
# transaction_channel_M                       2
# transaction_channel_W                       2
# transaction_channel_WEB                     2
# transaction_channel_mobile                  2
# transaction_channel_npm                     2
# transaction_channel_w                       2
# payer_email_encoded                        78
# payer_ip_encoded                            6
# payee_id_encoded                          136
# payment_gateway_bank_encoded               42
# payer_browser_encoded                     167
# transaction_payment_mode_anonymous_0        2
# transaction_payment_mode_anonymous_1        2
# transaction_payment_mode_anonymous_2        2
# transaction_payment_mode_anonymous_3        2
# ...

# %%
df= df.dropna()

# %%
print(df.isnull().sum())  # Check for missing values in each column
print(np.isnan(df).sum())  # Alternative way to check NaNs
# Out:
# transaction_amount                       0
# is_fraud                                 0
# transaction_channel_#                    0
# transaction_channel_1                    0
# transaction_channel_5666                 0
# transaction_channel_M                    0
# transaction_channel_W                    0
# transaction_channel_WEB                  0
# transaction_channel_mobile               0
# transaction_channel_npm                  0
# transaction_channel_w                    0
# payer_email_encoded                      0
# payer_ip_encoded                         0
# payee_id_encoded                         0
# payment_gateway_bank_encoded             0
# payer_browser_encoded                    0
# transaction_payment_mode_anonymous_0     0
# transaction_payment_mode_anonymous_1     0
# transaction_payment_mode_anonymous_2     0
# transaction_payment_mode_anonymous_3     0
# transaction_payment_mode_anonymous_4     0
# transaction_payment_mode_anonymous_5     0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
columns_to_standardize = ['transaction_amount', 'payer_email_encoded', 'payer_ip_encoded','payee_id_encoded','payment_gateway_bank_encoded','payer_browser_encoded']

scaler = MinMaxScaler()  # or MinMaxScaler()
scaler.fit(df[columns_to_standardize])  # Fit only on training data
# Out:
# MinMaxScaler()

# %%
df[columns_to_standardize] = scaler.transform(df[columns_to_standardize])

# %%
df.head(10)
# Out:
#    transaction_amount  is_fraud  transaction_channel_#  transaction_channel_1  \
# 0            0.000515         0                  False                  False
# 1            0.000085         0                  False                  False
# 2            0.000004         0                  False                  False
# 3            0.000014         0                  False                  False
# 4            0.000043         0                  False                  False
# 5            0.000501         0                  False                  False
# 6            0.000001         0                  False                  False
# 7            0.000043         0                  False                  False
# 8            0.000029         0                  False                  False
# 9            0.000101         0                  False                  False
#
#    transaction_channel_5666  transaction_channel_M  transaction_channel_W  \
# ...

# %%
df_fraud = df[df['is_fraud'] == 1].reset_index(drop=True)   # Reset index
df_non_fraud = df[df['is_fraud'] == 0].reset_index(drop=True)  # Reset index
df_fraud=df_fraud.drop(['is_fraud'], axis=1, errors='ignore')
df_non_fraud=df_non_fraud.drop(['is_fraud'], axis=1, errors='ignore')

# %%
print(df.isnull().sum())  # Check for missing values
print(np.isinf(df).sum())  # Check for infinite values
# Out:
# transaction_amount                       0
# is_fraud                                 0
# transaction_channel_#                    0
# transaction_channel_1                    0
# transaction_channel_5666                 0
# transaction_channel_M                    0
# transaction_channel_W                    0
# transaction_channel_WEB                  0
# transaction_channel_mobile               0
# transaction_channel_npm                  0
# transaction_channel_w                    0
# payer_email_encoded                      0
# payer_ip_encoded                         0
# payee_id_encoded                         0
# payment_gateway_bank_encoded             0
# payer_browser_encoded                    0
# transaction_payment_mode_anonymous_0     0
# transaction_payment_mode_anonymous_1     0
# transaction_payment_mode_anonymous_2     0
# transaction_payment_mode_anonymous_3     0
# transaction_payment_mode_anonymous_4     0
# transaction_payment_mode_anonymous_5     0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_non_fraud_train, x_non_fraud_test = train_test_split(
        df_non_fraud, test_size=0.20, random_state=42)

# %%
x_non_fraud_train.head(6)
# Out:
#         transaction_amount  transaction_channel_#  transaction_channel_1  \
# 70170             0.000006                  False                  False
# 40988             0.000006                  False                  False
# 156729            0.000001                  False                  False
# 70634             0.000091                  False                  False
# 19143             0.000029                  False                  False
# 70695             0.000010                  False                  False
#
#         transaction_channel_5666  transaction_channel_M  \
# 70170                      False                  False
# 40988                      False                  False
# 156729                     False                  False
# 70634                      False                  False
# 19143                      False                  False
# 70695                      False                  False
#
# ...

# %%
len(x_non_fraud_train)
# Out:
# 138274

# %%
from sklearn.utils import shuffle
x_non_fraud_train = shuffle(x_non_fraud_train , random_state=42).reset_index(drop=True)

# %%
x_non_fraud_train.head(6)
# Out:
#    transaction_amount  transaction_channel_#  transaction_channel_1  \
# 0            0.000029                  False                  False
# 1            0.000006                  False                  False
# 2            0.000048                  False                  False
# 3            0.000172                  False                  False
# 4            0.000008                  False                  False
# 5            0.000010                  False                  False
#
#    transaction_channel_5666  transaction_channel_M  transaction_channel_W  \
# 0                     False                  False                   True
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                     False                  False                  False
# 4                     False                  False                  False
# ...

# %%
df_non_fraud.head(6)
# Out:
#    transaction_amount  transaction_channel_#  transaction_channel_1  \
# 0            0.000515                  False                  False
# 1            0.000085                  False                  False
# 2            0.000004                  False                  False
# 3            0.000014                  False                  False
# 4            0.000043                  False                  False
# 5            0.000501                  False                  False
#
#    transaction_channel_5666  transaction_channel_M  transaction_channel_W  \
# 0                     False                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                     False                  False                  False
# 4                     False                  False                  False
# ...

# %%
from sklearn import metrics
import numpy as np

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
x_non_fraud_train.shape[1]
# Out:
# 28

# %%
from tensorflow.keras.metrics import AUC, Precision, Recall
import tensorflow.keras.backend as K
def reconstruction_loss(y_true, y_pred):
    return K.mean(K.square(y_true - y_pred))

# %%
from tensorflow.keras.losses import MeanSquaredError

# %%
model = Sequential()

# Encoder
model.add(Dense(128, input_dim=x_non_fraud_train.shape[1]))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.01))
model.add(Dropout(0.3))

model.add(Dense(64))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.01))
model.add(Dropout(0.3))

model.add(Dense(32))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.01))

# Bottleneck (Latent Space)
model.add(Dense(16))  # Reduced regularization
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.01))

# Decoder
model.add(Dense(32))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.01))
model.add(Dropout(0.3))

model.add(Dense(64))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.01))
model.add(Dropout(0.3))

model.add(Dense(128))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.01))

# Output layer (use sigmoid if data is normalized, else linear)
model.add(Dense(x_non_fraud_train.shape[1], activation='sigmoid'))  # Use 'linear' instead of 'sigmoid'

# Compile the model (remove AUC, Precision, and Recall)
model.compile(
    optimizer=Adam(),
    loss=MeanSquaredError(),
    metrics=['mae']  # Mean Absolute Error as a metric for reconstruction
)

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# Model Summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_99 (Dense)                     │ (None, 128)                 │           3,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
import tensorflow as tf

print("Num GPUs Available:", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled!")
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %%
# print("NaN in x_non_fraud_train:", np.isnan(x_non_fraud_train).sum())
# print("Inf in x_non_fraud_train:", np.isinf(x_non_fraud_train).sum())

# %%
import os

# Define the path where you want to save checkpoints in Google Drive
checkpoint_dir = "/content/drive/MyDrive/autoencoder_checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)  # Create the directory if it doesn't exist

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(checkpoint_dir, "model_best.keras"),  # Save in .keras format
    monitor="val_loss",  # Monitor validation loss
    save_best_only=True,  # Save only the best model
    mode="min",  # Lower val_loss is better
    verbose=1
)

# %%
history = model.fit(
    x_non_fraud_train, x_non_fraud_train,
    epochs=25, batch_size=64,
    validation_data=(x_non_fraud_test, x_non_fraud_test),
    callbacks=[early_stopping, reduce_lr, checkpoint_callback]  # Add checkpoint callback
)
# Out:
# Epoch 1/25
# 2161/2161 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0293 - mae: 0.0820
# Epoch 1: val_loss improved from inf to 0.00448, saving model to /content/drive/MyDrive/autoencoder_checkpoints/model_best.keras
# 2161/2161 ━━━━━━━━━━━━━━━━━━━━ 24s 7ms/step - loss: 0.0293 - mae: 0.0820 - val_loss: 0.0045 - val_mae: 0.0135 - learning_rate: 0.0010
# Epoch 2/25
# 2151/2161 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - mae: 0.0177
# Epoch 2: val_loss improved from 0.00448 to 0.00242, saving model to /content/drive/MyDrive/autoencoder_checkpoints/model_best.keras
# 2161/2161 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0064 - mae: 0.0177 - val_loss: 0.0024 - val_mae: 0.0077 - learning_rate: 0.0010
# Epoch 3/25
# 2156/2161 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0122
# Epoch 3: val_loss improved from 0.00242 to 0.00177, saving model to /content/drive/MyDrive/autoencoder_checkpoints/model_best.keras
# ...

# %%
df_fraud.head()
# Out:
#    transaction_amount  transaction_channel_#  transaction_channel_1  \
# 0            0.000357                  False                  False
# 1            0.000114                  False                  False
# 2            0.001334                  False                  False
# 3            0.001678                  False                  False
# 4            0.001285                  False                  False
#
#    transaction_channel_5666  transaction_channel_M  transaction_channel_W  \
# 0                     False                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                     False                  False                  False
# 4                     False                  False                  False
#
#    transaction_channel_WEB  transaction_channel_mobile  \
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Predict reconstructed outputs
x_non_fraud_pred = model.predict(x_non_fraud_test)
df_fraud_pred = model.predict(df_fraud)

# Compute RMSE for non-fraud test set
recon_error_non_fraud = np.sqrt(np.mean((x_non_fraud_test - x_non_fraud_pred) ** 2, axis=1))

# Compute RMSE for fraud set
recon_error_fraud = np.sqrt(np.mean((df_fraud - df_fraud_pred) ** 2, axis=1))

# Set threshold (Mean + 3*Std) from non-fraud data
threshold = np.mean(recon_error_non_fraud) + 3 * np.std(recon_error_non_fraud)

# Flag anomalies in fraud data
anomalies = recon_error_fraud > threshold

# Print results
print(f"Anomaly Threshold: {threshold}")
print(f"Number of detected anomalies: {np.sum(anomalies)} out of {len(anomalies)} fraud samples")

# Plot reconstruction error distributions
plt.figure(figsize=(10, 5))
plt.hist(recon_error_non_fraud, bins=50, alpha=0.7, label="Non-Fraud")
plt.hist(recon_error_fraud, bins=50, alpha=0.7, label="Fraud")
plt.axvline(threshold, color='red', linestyle='dashed', linewidth=2, label="Threshold")
plt.xlabel("Reconstruction Error (RMSE)")
plt.ylabel("Count")
plt.title("Reconstruction Error Distribution")
plt.legend()
plt.show()
# Out:
# 1081/1081 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Anomaly Threshold: 0.0745997951734653
# Number of detected anomalies: 0 out of 11 fraud samples

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):

    plt.figure(figsize=(12, 6))

    # Iterate through all keys in history and plot them
    for key in history.history.keys():
        plt.plot(history.history[key], label=key)

    plt.xlabel('Epochs')
    plt.ylabel('Value')
    plt.title('Training Metrics Over Epochs')
    plt.legend()
    plt.grid(True)
    plt.show()
plot_training_history(history)
